# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
raw_df = pd.read_csv("C:/Users/z003u0tx/Documents/UNI/Programmieren Date Science/Git/programming_python/data/bbc/bbc_data_raw.csv",header=0)
clean_df = pd.read_csv("C:/Users/z003u0tx/Documents/UNI/Programmieren Date Science/Git/programming_python/data/bbc/bbc_data_clean.csv",header=0)

# %%
raw_df.head()
# Out:
#                                  art_id  \
# 0  851b1a18-afee-4e1b-98a8-8c9618643f6c
# 1  a0f56cd2-95e6-43a1-8c02-cea9d2b56498
# 2  5ef68f5c-1e9a-443f-a0ae-d7a097aa4e23
# 3  bb077fc4-3383-439c-92fe-a02800310d91
# 4  bef68156-a99b-4ee6-b047-a9a36be6f74d
#
#                                            art_title  \
# 0  Hong Kong police evict protesters who stormed ...
# 1  Hammond says Tory leadership candidates must '...
# 2  MPs call for urgent action over homophobia hat...
# 3  The Killers, Stormzy, Kylie Minogue, The Cure ...
# 4  Jeremy Corbyn: No 10 criticises civil servants...
#
#                                          art_subhead     art_date  \
# 0  Police firing tear gas have evicted protesters...  2 July 2019
# 1  The chancellor has called on Tory leadership c...  1 July 2019
# 2  MPs have called for "urgent action" from the g...  1 July 2019
# 3  The dust is settling, the debris is being clea...  1 July 2019
# ...

# %%
raw_df.tail()
# Out:
#                                      art_id  \
# 14397  1473a214-f56e-41c7-90d9-4a674a63779d
# 14398  bdbcc803-a053-4812-bd87-29694ebb9cc3
# 14399  178645d1-a878-4c9b-93f7-f6f2d6e21b33
# 14400  506f914a-21fc-4fd8-aacc-9a5a863cb94b
# 14401  2d36c01c-21bb-453d-b17d-27687f757ac6
#
#                                                art_title  \
# 14397  Britney Spears appears to endorse the #FreeBri...
# 14398  Mulan: Why Disney's latest reboot is facing bo...
# 14399  Azeem Rafiq: Yorkshire's former spinner on 'dr...
# 14400  Luis Suarez agrees deal with Juventus - Guille...
# 14401  Harry Maguire: England boss Gareth Southgate o...
#
#                                              art_subhead          art_date  \
# 14397  Britney Spears has welcomed public scrutiny of...  4 September 2020
# 14398  It's one of the first big movie releases since...  4 September 2020
# 14399                                                NaN        1 hour ago
# ...

# %%
clean_df.head()
# Out:
#                                  art_id  \
# 0  851b1a18-afee-4e1b-98a8-8c9618643f6c
# 1  a0f56cd2-95e6-43a1-8c02-cea9d2b56498
# 2  5ef68f5c-1e9a-443f-a0ae-d7a097aa4e23
# 3  bb077fc4-3383-439c-92fe-a02800310d91
# 4  bef68156-a99b-4ee6-b047-a9a36be6f74d
#
#                                            art_title  \
# 0  hong kong police evict protesters who stormed ...
# 1  hammond says tory leadership candidates must '...
# 2  mps call for urgent action over homophobia hat...
# 3  the killers, stormzy, kylie minogue, the cure ...
# 4  jeremy corbyn: no 10 criticises civil servants...
#
#                                          art_subhead     art_date  \
# 0  police firing tear gas have evicted protesters...  2 july 2019
# 1  the chancellor has called on tory leadership c...  1 july 2019
# 2  mps have called for "urgent action" from the g...  1 july 2019
# 3  the dust is settling, the debris is being clea...  1 july 2019
# ...

# %%
clean_df.tail()
# Out:
#                                      art_id  \
# 14363  1473a214-f56e-41c7-90d9-4a674a63779d
# 14364  bdbcc803-a053-4812-bd87-29694ebb9cc3
# 14365  178645d1-a878-4c9b-93f7-f6f2d6e21b33
# 14366  506f914a-21fc-4fd8-aacc-9a5a863cb94b
# 14367  2d36c01c-21bb-453d-b17d-27687f757ac6
#
#                                                art_title  \
# 14363  britney spears appears to endorse the #freebri...
# 14364  mulan: why disney's latest reboot is facing bo...
# 14365  azeem rafiq: yorkshire's former spinner on 'dr...
# 14366  luis suarez agrees deal with juventus - guille...
# 14367  harry maguire: england boss gareth southgate o...
#
#                                              art_subhead          art_date  \
# 14363  britney spears has welcomed public scrutiny of...  4 september 2020
# 14364  it's one of the first big movie releases since...  4 september 2020
# 14365                                                NaN        1 hour ago
# ...

# %%
raw_df.describe()
# Out:
#                                       art_id                    art_title  \
# count                                  14402                        14066
# unique                                 14402                        14050
# top     851b1a18-afee-4e1b-98a8-8c9618643f6c  Coronavirus: Morning update
# freq                                       1                            7
#
#        art_subhead      art_date   art_authors    art_tags  \
# count        10923         12108         13478       10568
# unique       10604           417          1278        9336
# top              .  31 July 2020  31 July 2020  News Daily
# freq            50            74            64          86
#
#                                                  art_body comments_allowed  \
# count                                               14402            14402
# unique                                              14374                2
# ...

# %%
clean_df.describe()
# Out:
#                                       art_id                    art_title  \
# count                                  14368                        14033
# unique                                 14368                        14018
# top     851b1a18-afee-4e1b-98a8-8c9618643f6c  coronavirus: morning update
# freq                                       1                            7
#
#        art_subhead      art_date   art_authors    art_tags  \
# count        10892         12077         13444       10541
# unique       10578           417           984        9336
# top              .  31 july 2020  31 july 2020  news daily
# freq            60            74            65          86
#
#                                                  art_body comments_allowed  \
# count                                               14368            14368
# unique                                              14368                1
# ...

# %%
raw_df['art_id']
# Out:
# 0        851b1a18-afee-4e1b-98a8-8c9618643f6c
# 1        a0f56cd2-95e6-43a1-8c02-cea9d2b56498
# 2        5ef68f5c-1e9a-443f-a0ae-d7a097aa4e23
# 3        bb077fc4-3383-439c-92fe-a02800310d91
# 4        bef68156-a99b-4ee6-b047-a9a36be6f74d
#                          ...
# 14397    1473a214-f56e-41c7-90d9-4a674a63779d
# 14398    bdbcc803-a053-4812-bd87-29694ebb9cc3
# 14399    178645d1-a878-4c9b-93f7-f6f2d6e21b33
# 14400    506f914a-21fc-4fd8-aacc-9a5a863cb94b
# 14401    2d36c01c-21bb-453d-b17d-27687f757ac6
# Name: art_id, Length: 14402, dtype: object

# %%
raw_df.loc[40]
# Out:
# art_id                           d0edfc32-fe07-4c37-8e09-87f53fff2c19
# art_title           Taylor Swift v Scooter Braun: Is it personal o...
# art_subhead         Taylor Swift has accused music mogul Scooter B...
# art_date                                                  1 July 2019
# art_authors                                               1 July 2019
# art_tags                                          Taylor Swift, Music
# art_body            \r\nTaylor Swift has accused music mogul Scoot...
# comments_allowed                                                False
# art_media                                                         bbc
# Name: 40, dtype: object

# %%
raw_df.drop('art_id',1) #Drop column art id
# Out:
# C:\Users\z003u0tx\AppData\Local\Temp\ipykernel_27668\1747000776.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   raw_df.drop('art_id',1)
#                                                art_title  \
# 0      Hong Kong police evict protesters who stormed ...
# 1      Hammond says Tory leadership candidates must '...
# 2      MPs call for urgent action over homophobia hat...
# 3      The Killers, Stormzy, Kylie Minogue, The Cure ...
# 4      Jeremy Corbyn: No 10 criticises civil servants...
# ...                                                  ...
# 14397  Britney Spears appears to endorse the #FreeBri...
# 14398  Mulan: Why Disney's latest reboot is facing bo...
# 14399  Azeem Rafiq: Yorkshire's former spinner on 'dr...
# 14400  Luis Suarez agrees deal with Juventus - Guille...
# 14401  Harry Maguire: England boss Gareth Southgate o...
#
# ...

# %%
raw_df.drop(1,0) #Drop row 1
raw_df.drop(1,0,inplace=true) #Drop and creates no copy but deletes from DF

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14402 entries, 0 to 14401
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   art_id            14402 non-null  object
#  1   art_title         14066 non-null  object
#  2   art_subhead       10923 non-null  object
#  3   art_date          12108 non-null  object
#  4   art_authors       13478 non-null  object
#  5   art_tags          10568 non-null  object
#  6   art_body          14402 non-null  object
#  7   comments_allowed  14402 non-null  bool
#  8   art_media         14402 non-null  object
# dtypes: bool(1), object(8)
# memory usage: 914.3+ KB

# %%
raw_df.head()
# Out:
#                                  art_id  \
# 0  851b1a18-afee-4e1b-98a8-8c9618643f6c
# 1  a0f56cd2-95e6-43a1-8c02-cea9d2b56498
# 2  5ef68f5c-1e9a-443f-a0ae-d7a097aa4e23
# 3  bb077fc4-3383-439c-92fe-a02800310d91
# 4  bef68156-a99b-4ee6-b047-a9a36be6f74d
#
#                                            art_title  \
# 0  Hong Kong police evict protesters who stormed ...
# 1  Hammond says Tory leadership candidates must '...
# 2  MPs call for urgent action over homophobia hat...
# 3  The Killers, Stormzy, Kylie Minogue, The Cure ...
# 4  Jeremy Corbyn: No 10 criticises civil servants...
#
#                                          art_subhead     art_date  \
# 0  Police firing tear gas have evicted protesters...  2 July 2019
# 1  The chancellor has called on Tory leadership c...  1 July 2019
# 2  MPs have called for "urgent action" from the g...  1 July 2019
# 3  The dust is settling, the debris is being clea...  1 July 2019
# ...

# %%
raw_df.drop('art_media',1).drop('comments_allowed',1)
